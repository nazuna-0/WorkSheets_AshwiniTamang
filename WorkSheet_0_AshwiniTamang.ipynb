# %% [markdown]
# <a href="https://colab.research.google.com/github/nazuna-0/WorkSheet-0_AshwiniTamang/blob/main/WorkSheet_0_AshwiniTamang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1**

# %%
# Task 1
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# making empty lists
low = []
mid = []
high = []

for tup in time_data:
  for time in tup:
      if time < 3:
        low.append(time)
      elif 3 <= time <= 5:
        mid.append(time)
      else:
        high.append(time)

print(low)
print(mid)
print(high)


# Task 2 (len(), is used get the length of the list)
count_low = len(low)
count_mid = len(mid)
count_high = len(high)

print(count_low)
print(count_mid)
print(count_high)

#Task 3
# Formula: mins = hrs x 60
study_minutes = []

for tup in time_data:
  for hour in tup:
    study_minutes.append(hour * 60)
print(f"Into Minutes = {study_minutes}")

# Task 4
study_hours =[]
entertainment_hours = []
sleep_hours = []

for hours in time_data:
  study, entertainment, sleep = hours
  study_hours.append(study)
  entertainment_hours.append(entertainment)
  sleep_hours.append(sleep)
# average avg = sum of all values / num of values
avg_study = sum(study_hours)/ len(study_hours)


print(f"average study hours = {avg_study} ")


# Task 5
import matplotlib.pyplot as plt
# scatter plt
plt.scatter(study_hours, sleep_hours, color ='orange')
# lables
plt.title("Study vs Sleep Pattern")
plt.ylabel("Sleep Hours")
plt.xlabel("Study Hours")
# Out:
# [2.0, 1.5, 2.5, 2.0, 1.5, 2.5, 1.0, 2.0, 2.0, 1.5, 2.5, 2.5, 2.0, 2.5]
# [3.5, 5.0, 3.0, 4.0, 4.5, 3.0, 3.5, 4.5, 3.0, 3.0, 4.0, 4.0, 5.0, 3.5]
# [7.0, 6.5, 8.0, 6.0, 9.0, 7.5, 5.5, 6.0, 8.5, 7.0, 7.5, 6.0, 6.0, 8.0, 7.0, 6.5, 7.0]
# 14
# 14
# 17
# Into Minutes = [210.0, 120.0, 420.0, 300.0, 90.0, 390.0, 150.0, 180.0, 480.0, 240.0, 120.0, 360.0, 90.0, 270.0, 540.0, 180.0, 150.0, 450.0, 330.0, 60.0, 360.0, 120.0, 210.0, 510.0, 270.0, 120.0, 420.0, 180.0, 180.0, 450.0, 360.0, 90.0, 360.0, 150.0, 240.0, 480.0, 240.0, 150.0, 420.0, 300.0, 120.0, 390.0, 210.0, 150.0, 420.0]
# average study hours = 3.7
# Text(0.5, 0, 'Study Hours')

# %% [markdown]
# **Task 2**
#
# count_low = len(low)
# count_mid = len(mid)
# count_high = len(high)
#
# print(count_low)
# print(count_mid)
# print(count_high)
#
# 14,14,17

# %%
#8.1.1 [Recursion]

def sum_nested_list(nested_list):
    total = 0

    for element in nested_list:
      if isinstance(element, list):
      # isinstance(value, type)
          total += sum_nested_list(element)
      else:
          total += element
    return total

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
print(sum_nested_list(nested_list))
# Out:
# 36

# %%
# Task 2

def generate_permutations(s):

    if len(s) == 1:
        return [s]

    result = []

    for i in range(len(s)):
        current_char = s[i]
        remaining = s[:i] + s[i+1:]

        for p in generate_permutations(remaining):
            result.append(current_char + p)

    return result

print(generate_permutations("jhk"))
# Out:
# ['jhk', 'jkh', 'hjk', 'hkj', 'kjh', 'khj']

# %%
# Task 3

directory_structure = {
    "file1.txt": 600,
    "file2.txt": 800,
    "subdir1": {
        "file3.txt": 200,
    }
}

def calculate_directory_size(directory):
    total_size = 0

    for key, value in directory.items():
        if isinstance(value, dict):

            total_size += calculate_directory_size(value)
        else:
            total_size += value

    return total_size

print(calculate_directory_size(directory_structure))
# Out:
# 1600

# %%
# 8.2.1
#Task 1

def min_coins(coins, amount):

  dp = [float('inf')] * (amount + 1)
  dp[0] = 0


  for coin in coins:
    for i in range(coin, amount + 1):
      dp[i] = min(dp[i], dp[i - coin] + 1)
  return dp[amount] if dp[amount] != float('inf') else -1

coins = [1,2,5]
amount = 11
print(min_coins(coins, amount))

print(min_coins([2], 3))
# Out:
# 3
# -1

# %%
# Task 2
#LCS Longest Common Subsequence

def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = 1 + dp[i - 1][j - 1]
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

s1 = ""
s2 = "ace"
print(longest_common_subsequence(s1, s2))
# Out:
# 3

# %%
# Task 3

weights = [8, 2, 4, ]
values = [7, 5, 2]
capacity = 9


def knapsack(weights, values, capacity):
    n = len(weights)

    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(
                    dp[i - 1][w],
                    values[i - 1] + dp[i - 1][w - weights[i - 1]]
                )
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


print(knapsack(weights, values, capacity))
# Out:
# 7
