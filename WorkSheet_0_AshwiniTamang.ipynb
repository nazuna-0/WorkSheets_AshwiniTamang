# %% [markdown]
# <a href="https://colab.research.google.com/github/nazuna-0/WorkSheets_AshwiniTamang/blob/main/WorkSheet_0_AshwiniTamang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1**

# %%
# Task 1
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 4.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 5.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 2.0, 6.0), (2.0, 3.5, 8.5), (3.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# making empty lists
low = []
mid = []
high = []

# to extract study hour
for tup in time_data:
  study = tup[0]

  if study < 3:
    low.append(study)
  elif 3 <= study <= 5:
    mid.append(study)
  else:
    high.append(study)

print(low)
print(mid)
print(high)


# Task 2 (len(), is used get the length of the list)
count_low = len(low)
count_mid = len(mid)
count_high = len(high)

print(count_low)
print(count_mid)
print(count_high)

#Task 3
# Formula: mins = hrs x 60
study_minutes = []

for tup in time_data:
  # to get the first element from the main tuple. i.e study hours
  study_hours = tup[0]
  study_minutes.append(study_hours * 60)
print(f"Into Minutes = {study_minutes}")


# Task 4
study_hours =[]
entertainment_hours = []
sleep_hours = []

for hours in time_data:
  # multiple assign at once
  study, entertainment, sleep = hours
  study_hours.append(study)
  entertainment_hours.append(entertainment)
  sleep_hours.append(sleep)


# average avg = sum of all values / num of values
avg_study = sum(study_hours)/ len(study_hours)

print(f"average study hours = {avg_study} ")


# Task 5
# graph plot python built in
import matplotlib.pyplot as plt
# scatter plt
plt.scatter(study_hours, sleep_hours, color ='orange')
# lables
plt.title("Study vs Sleep Pattern")
plt.ylabel("Sleep Hours")
plt.xlabel("Study Hours")
# Out:
# [2.5, 1.5, 2.0, 2.5]
# [3.5, 5.0, 4.0, 3.0, 3.5, 3.0, 4.0, 5.0, 3.5]
# [5.5, 6.0]
# 4
# 9
# 2
# Into Minutes = [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 210.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]
# average study hours = 3.6333333333333333
# Text(0.5, 0, 'Study Hours')

# %%
#8.1.1 [Recursion]

# we need to use recursion to loop and get the variables inside the sub lists.

def sum_nested_list(nested_list):
    total = 0

    for element in nested_list:
      if isinstance(element, list):
      # isinstance(value, type)
          total += sum_nested_list(element)
      else:
          total += element
    return total

nested_list = [2, [2, [5, 4], 5],6, [7, 8]]
print(sum_nested_list(nested_list))
# Out:
# 36

# %%
# Task 2

# all possible results

def generate_permutations(s):
    if len(s) == 1:
        return [s]

    result = []

    for i in range(len(s)):
        current_char = s[i]
        remaining = s[:i] + s[i+1:]

        for p in generate_permutations(remaining):
            result.append(current_char + p)

    return result

print(generate_permutations("jhk"))
# Out:
# ['jhk', 'jkh', 'hjk', 'hkj', 'kjh', 'khj']

# %%
# Task 3c Total size of file in KB

#
directory_structure = {
    "file1.txt": 600,
    "file2.txt": 800,
    "subdir1": {
        "file3.txt": 200,
    }
}

def calculate_directory_size(directory):
    total_size = 0

    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            total_size += value

    return total_size

print(calculate_directory_size(directory_structure))
# Out:
# 1600

# %%
# 8.2.1
#Task 1

def min_coins(coins, amount):

  dp = [float('inf')] * (amount + 1)
  #set to inifity bcuz the value is unknown
  dp[0] = 0


  for coin in coins:
    for i in range(coin, amount + 1):
      dp[i] = min(dp[i], dp[i - coin] + 1)
  return dp[amount]if dp[amount] != float('inf') else -1

coins = [1,2,5]
amount = 11
print(min_coins(coins, amount))

print(min_coins([2], 3))
# Out:
# 3
# -1

# %%
# Task 2
#LCS Longest Common Subsequence

def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = 1 + dp[i - 1][j - 1]
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

s1 = ""
s2 = "ace"
print(longest_common_subsequence(s1, s2))
# Out:
# 3

# %%
# Task 3

weights = [8, 2, 4, ]
values = [7, 5, 2]
capacity = 9


def knapsack(weights, values, capacity):
    n = len(weights)

    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(
                    dp[i - 1][w],
                    values[i - 1] + dp[i - 1][w - weights[i - 1]]
                )
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


print(knapsack(weights, values, capacity))
# Out:
# 7
