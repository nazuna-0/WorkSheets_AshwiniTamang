# %% [markdown]
# <a href="https://colab.research.google.com/github/nazuna-0/WorkSheets_AshwiniTamang/blob/WorkSheet---5/WorkSheet5_AshwiniTamang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step -1- Data Understanding, Analysis and Preparations:**

# %%
from google.colab import files
import pandas as pd


uploaded = files.upload()
stds = pd.read_csv("student.csv")
# Out:
#      <input type="file" id="files-5d1e40af-f5f7-4f91-abc0-810c538b9e4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d1e40af-f5f7-4f91-abc0-810c538b9e4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Objective of the Task
# To Predict the marks obtained in writing based on the marks of Math and Reading.**

# %% [markdown]
# **• To - Do - 1:**

# %% [markdown]
# Exercise 1: Exploratory Data Analysis (EDA)
#
# Exercise 2: Matrix Formulation (Y = WᵀX)
#
# Exercise 3: Data Splitting

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
#1
stds.info()

#2
stds.head()
stds.tail()

#3
stds.info()

#4
stds.describe()

#5
#Split your data into Feature (X) and Label (Y).

# Features: Math & Reading marks
X = stds[['Math', 'Reading']]
# Target: Writing marks
Y = stds['Writing']


print(f"{X.shape}")
print(f"{Y.shape}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     1000 non-null   int64
#  1   Reading  1000 non-null   int64
#  2   Writing  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     1000 non-null   int64
#  1   Reading  1000 non-null   int64
#  2   Writing  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB
# (1000, 2)
# (1000,)

# %% [markdown]
# **• To - Do - 2:**

# %% [markdown]
# Exercise 4: Defining the Mean Squared Error (MSE) Cost Function
#
# Exercise 5: Cost Function Validation (Test Case)

# %%
def train_test_split_scratch(X, Y, test_size=0.2, seed=42):
    # spliting data
    np.random.seed(seed)
    idx = np.arange(len(X))
    np.random.shuffle(idx)

    # no of test samples
    split = int(len(X) * test_size)

    # test indices
    test_idx = idx[:split]
    # training indices
    train_idx = idx[split:]

    # return training and testing sets
    return X[train_idx], X[test_idx], Y[train_idx], Y[test_idx]

    X_train, X_test, Y_train, Y_test = train_test_split_scratch(X, Y)

print("\nX_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (800, 2)
# X_test shape: (200, 2)
# Y_train shape: (800,)
# Y_test shape: (200,)

# %%
# Define the cost function
def cost_function(X, Y, W):
    #no. of samples
    n = len(Y)
    #predicted values
    Y_pred = np.dot(X, W)
    #formual
    cost = (1 / (2 * n)) * np.sum((Y_pred - Y) ** 2)
    return cost

# %% [markdown]
# **• To - Do - 3:**
#
# Exercise 6: Implementing Gradient Descent from Scratch
#
# Exercise 7: Gradient Descent Verification

# %%
def gradient_descent(X, Y, W, alpha, iterations):
    m = len(Y)
    cost_history = []

    for _ in range(iterations):
        Y_pred = np.dot(X, W)
        loss = Y_pred - Y
        dw = (1 / m) * np.dot(X.T, loss)
        W = W - alpha * dw
        cost = cost_function(X, Y, W)
        cost_history.append(cost)

    return W, cost_history

# %% [markdown]
# **• To - Do - 4:**

# %% [markdown]
# Exercise 8: Root Mean Squared Error (RMSE) Function
#
# Exercise 9: Coefficient of Determination (R^2) Function

# %%
def rmse(Y, Y_pred):
    return np.sqrt(np.mean((Y - Y_pred) ** 2))

# %%
def r2(Y, Y_pred):
    mean_y = np.mean(Y)
    ss_tot = np.sum((Y - mean_y) ** 2)
    ss_res = np.sum((Y - Y_pred) ** 2)
    return 1 - (ss_res / ss_tot)

# %% [markdown]
# **• To - Do - 5:**

# %% [markdown]
# **Main Function to Integrate All Steps:**

# %% [markdown]
# Exercise 10: The Main Execution Pipeline
#
# xercise 11: Analysis and Findings

# %%
def main():
    # Step 1: Load the dataset
    data = pd.read_csv('student.csv')

    # Step 2: Split the data into features (X) and target (Y)
    X = data[['Math', 'Reading']].values
    Y = data['Writing'].values

    # Step 3: Split the data into training and test sets
    # Using the scratch function we built to avoid the iloc error
    X_train, X_test, Y_train, Y_test = train_test_split_scratch(X, Y, test_size=0.2, seed=42)

    # Step 4: Initialize weights (W) to zeros, learning rate and number of iterations
    W = np.zeros(X_train.shape[1])
    alpha = 0.00001
    iterations = 1000

    # Step 5: Perform Gradient Descent
    W_optimal, cost_history = gradient_descent(X_train, Y_train, W, alpha, iterations)

    # Step 6: Make predictions on the test set
    Y_pred = np.dot(X_test, W_optimal)

    # Step 7: Evaluate the model using RMSE and R-Squared
    model_rmse = rmse(Y_test, Y_pred)
    model_r2 = r2(Y_test, Y_pred)

    # Step 8: Output the results
    print("Final Weights:", W_optimal)
    print("Cost History (First 10 iterations):", cost_history[:10])
    print("RMSE on Test Set:", model_rmse)
    print("R-Squared on Test Set:", model_r2)

# Execute the main function
if __name__ == "__main__":
    main()
# Out:
# Final Weights: [0.34811659 0.64614558]
# Cost History (First 10 iterations): [np.float64(2013.165570783755), np.float64(1640.286832599692), np.float64(1337.0619994901588), np.float64(1090.4794892850578), np.float64(889.9583270083234), np.float64(726.8940993009545), np.float64(594.2897260808594), np.float64(486.4552052951635), np.float64(398.7634463599484), np.float64(327.4517147324688)]
# RMSE on Test Set: 5.2798239764188635
# R-Squared on Test Set: 0.8886354462786421

# %% [markdown]
# **Tests**

# %%
X_test = np.array([[1, 2], [3, 4], [5, 6]])
Y_test = np.array([3, 7, 11])
W_test = np.array([1, 1])

cost = cost_function(X_test, Y_test, W_test)

print(f"Cost function output: {cost}")
if np.isclose(cost, 0):
    print("Result: Success! Proceed Further.")
else:
    print("Result: Something went wrong. Re-check your cost_function.")
# Out:
# Cost function output: 0.0
# Result: Success! Proceed Further.

# %%
np.random.seed(0)
X_test_gd = np.random.rand(100, 3)
Y_test_gd = np.random.rand(100)
W_init = np.zeros(3)

# Run the function
final_params, cost_history = gradient_descent(X_test_gd, Y_test_gd, W_init, 0.01, 100)

print("Final Parameters:", final_params)
print("First 5 Cost values:", cost_history[:5])
# Out:
# Final Parameters: [0.15296994 0.16475757 0.16080411]
# First 5 Cost values: [np.float64(0.15059661786297981), np.float64(0.14896115898591414), np.float64(0.14735331507172653), np.float64(0.1457726192196863), np.float64(0.14421861242432132)]
